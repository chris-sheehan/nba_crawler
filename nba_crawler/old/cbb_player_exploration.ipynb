# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.ensemble import RandomForestRegressor as RFR

# %%
dfTeams = pd.read_csv('teams.csv')
dfRosters = pd.read_csv('rosters.csv')

# %%
dfAll = dfTeams.merge(dfRosters,
                      how = 'left',
                      on = ['tm_link', 'year']
                      )

# %%
dfAll['conf_clean'] = dfAll.conference.apply(lambda c: c.split(' (')[0])

# %%
conferences = {c : ii for ii, c in enumerate(sorted(dfAll.conf_clean.unique()))}
dfAll['conference_id'] = dfAll.conf_clean.apply(lambda c: conferences[c])

# %%
dfAll['pos_id'], pos_key = pd.factorize(dfAll.pos_primary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6745158a293a> in <module>()
# ----> 1 dfAll['pos_id'], pos_key = pd.factorize(dfAll.pos_primary)
#
# /home/chris/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pos_primary'

# %%
dfAll.head()
# Out:
#   conference  team tm_link  year class  ht         player pos  \
# 0        ACC  Duke    duke  2001    SR  80  Shane Battier   F
# 1        ACC  Duke    duke  2001    SO  81  Carlos Boozer   C
# 2        ACC  Duke    duke  2001    SO  76    Andy Borman   G
# 3        ACC  Duke    duke  2001    SO  70  Andre Buckner   G
# 4        ACC  Duke    duke  2001    SR  75  Ryan Caldbeck   G
#
#        player_link conf_clean  conference_id
# 0  shane-battier-1        ACC              3
# 1  carlos-boozer-1        ACC              3
# 2    andy-borman-1        ACC              3
# 3  andre-buckner-1        ACC              3
# 4  ryan-caldbeck-1        ACC              3

# %% [markdown]
# ### Clean Up Classes

# %%
# Manually change C -> SO
dfAll.loc[dfAll['class'] == 'C', 'class'] = 'SO'
dfAll['class'] = dfAll['class'].apply(lambda c: c.upper() if not pd.isnull(c) else np.nan)

# %%
fixed_classes = {54441 : 'JR',
                 60813 : 'FR',
                 60814 : 'FR',
                 62037 : 'FR'
                }
for fc in fixed_classes:
    dfAll.loc[fc, 'class'] = fixed_classes[fc]

# %%
# Set all grad school students to SR (only ~60 players)
dfAll.loc[dfAll['class'].isin(['GS', 'GR']), 'class'] = 'SR'

# %%
# Remove "Others"
dfAll = dfAll.loc[dfAll.player != 'Others']

# %%
class_mapping = {
    'SR' : 4,
    'JR' : 3,
    'SO' : 2,
    'FR' : 1
}
dfAll['class_id'] = dfAll['class'].apply(lambda c: class_mapping[c] if pd.notnull(c) else 0)
# Out:
# /home/chris/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Clean Up Positions

# %%
dfAll.pos = dfAll.pos.apply(lambda p: p.upper() if not pd.isnull(p) else np.nan)
# Out:
# /home/chris/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1974: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
# Change pos == 'W' (n = 2) to other years' position (Bo Barnes (G), Jalen Moore (F))
# dfAll[dfAll.pos == 'W']
dfAll.loc[dfAll.player == 'Bo Barnes', 'pos'] = 'G'
dfAll.loc[dfAll.player == 'Jalen Moore', 'pos'] = 'F'
# Out:
# /home/chris/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Creare Column for "Multi-Position"
dfAll['multipos'] = dfAll.pos.apply(lambda p: 0 if pd.isnull(p) else ('-' in p))
# Out:
# /home/chris/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app

# %%
# Create Column for Primary Position
dfAll['pos_primary'] = dfAll.pos.apply(lambda p: np.nan if pd.isnull(p) else p[0])
# Out:
# /home/chris/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app

# %%
dfAll['pos_id'], pos_key = pd.factorize(dfAll.pos_primary)
# Out:
# /home/chris/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# dfAll.to_csv('rosters_cleaned.csv', index = False)

# %% [markdown]
# ### Clean Up Heights

# %%
dfAll.ht.unique()
# Out:
# array([ 80.,  81.,  76.,  70.,  75.,  82.,  73.,  78.,  83.,  74.,  71.,
#         79.,  77.,  85.,  84.,  72.,  nan,  69.,  87.,  65.,  86.,  66.,
#         68.,  67.,  64.,  90.,  60.,  63.,  89.,  91.,  88.,  62.])

# %%
dfAll.insert(6, 'ht_imp', dfAll.ht.isnull())

# %%
# Fill NA heights via...

Xcol = ['year', 'class_id', 'multipos', 'conference_id', 'pos_id']
ycol = 'ht'

rfr_best = RFR(n_estimators = 100,
               # max_features = 10,
               max_depth = 10,
               min_samples_split = 2,
               min_samples_leaf = 3
               )

Xtrain = dfAll.loc[dfAll.ht.notnull(), Xcol]
ytrain = dfAll.loc[dfAll.ht.notnull(), ycol]
Xtest = dfAll.loc[dfAll.ht.isnull(), Xcol]

rfr_best.fit(Xtrain, ytrain)
ypred = rfr_best.predict(Xtest)

dfAll.loc[dfAll.ht.isnull(), ycol] = ypred

# %%
dfAll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67011 entries, 0 to 67023
# Data columns (total 16 columns):
# conference       67011 non-null object
# team             67011 non-null object
# tm_link          67011 non-null object
# year             67011 non-null float64
# class            66898 non-null object
# ht               67011 non-null float64
# ht_imp           67011 non-null bool
# player           67007 non-null object
# pos              66116 non-null object
# player_link      67007 non-null object
# conf_clean       67011 non-null object
# conference_id    67011 non-null int64
# class_id         67011 non-null int64
# multipos         67011 non-null object
# pos_primary      66116 non-null object
# pos_id           67011 non-null int64
# dtypes: bool(1), float64(2), int64(3), object(10)
# memory usage: 8.2+ MB

# %%
dfAll[dfAll.pos_primary.isnull()]
# Out:
#              conference                  team               tm_link  year  \
# 23               Pac-10               Arizona               arizona  2001
# 127              Big 12                Kansas                kansas  2001
# 148                 ACC              Virginia              virginia  2001
# 301          SEC (East)             Tennessee             tennessee  2001
# 323             Big Ten             Wisconsin             wisconsin  2001
# 325             Big Ten             Wisconsin             wisconsin  2001
# 332             Big Ten             Wisconsin             wisconsin  2001
# 405     CUSA (American)             Charlotte             charlotte  2001
# 443          SEC (West)               Alabama               alabama  2001
# 545             Big Ten            Penn State            penn-state  2001
# 552             Big Ten            Penn State            penn-state  2001
# 610     Big East (West)            Georgetown            georgetown  2001
# 617                 WAC       Texas Christian       texas-christian  2001
# 635          SEC (West)                Auburn                auburn  2001
# 797     Big East (East)           Connecticut           connecticut  2001
# 846                 WCC            Pepperdine            pepperdine  2001
# 847                 WCC            Pepperdine            pepperdine  2001
# 946     Sun Belt (East)      Western Kentucky      western-kentucky  2001
# 991              Big 12              Nebraska              nebraska  2001
# 996              Big 12              Nebraska              nebraska  2001
# 1005             Big 12              Nebraska              nebraska  2001
# 1136                MVC         Indiana State         indiana-state  2001
# 1148                MVC         Indiana State         indiana-state  2001
# 1410    Big East (West)         West Virginia         west-virginia  2001
# 1414    Big East (West)         West Virginia         west-virginia  2001
# 1424            Big Ten          Northwestern          northwestern  2001
# 1426            Big Ten          Northwestern          northwestern  2001
# 1432            Big Ten          Northwestern          northwestern  2001
# 1632               A-10              La Salle              la-salle  2001
# 1645            MW Coll       Cleveland State       cleveland-state  2001
# ...                 ...                   ...                   ...   ...
# 41834               NEC         Robert Morris         robert-morris  2010
# 41864               OVC           Austin Peay           austin-peay  2010
# 42011        MAC (West)            Ball State            ball-state  2010
# 42156          Big West  Cal State Northridge  cal-state-northridge  2010
# 42184            Summit    South Dakota State    south-dakota-state  2010
# 42251              MEAC               Hampton               hampton  2010
# 42355           Horizon      Illinois-Chicago      illinois-chicago  2010
# 42473               OVC    Jacksonville State    jacksonville-state  2010
# 42474               OVC    Jacksonville State    jacksonville-state  2010
# 42506              SWAC   Arkansas-Pine Bluff   arkansas-pine-bluff  2010
# 42581              MEAC        Delaware State        delaware-state  2010
# 42605           Patriot                  Army                  army  2010
# 42803  Southland (East)        Nicholls State        nicholls-state  2010
# 42815  Southland (West)                 Lamar                 lamar  2010
# 43007              MEAC    North Carolina A&T     north-carolina-at  2010
# 43147               Ivy          Pennsylvania          pennsylvania  2010
# 43239              SWAC         Alabama State         alabama-state  2010
# 43347              SWAC          Prairie View          prairie-view  2010
# 43413              MAAC                Marist                marist  2010
# 43430               GWC    Texas-Pan American    texas-pan-american  2010
# 43466             A-Sun               Stetson               stetson  2010
# 43618              SWAC             Grambling             grambling  2010
# 43621              SWAC             Grambling             grambling  2010
# 43641              SWAC              Southern              southern  2010
# 43648              SWAC          Alcorn State          alcorn-state  2010
# 43659              SWAC          Alcorn State          alcorn-state  2010
# 45848        MAC (West)            Ball State            ball-state  2011
# 47377   Sun Belt (East)         South Alabama         south-alabama  2011
# 62258              SWAC             Grambling             grambling  2014
# 66705              MEAC       Bethune-Cookman       bethune-cookman  2015
#
#       class         ht ht_imp               player  pos  \
# 23       FR  77.000000  False      Mike Schwertley  NaN
# 127      JR  81.000000  False      Todd Kappelmann  NaN
# 148      SO  77.000000  False          Roger Mason  NaN
# 301      FR  80.000000  False         Andy Ikeakor  NaN
# 323      FR  77.584017   True          Ricky Bower  NaN
# 325      FR  77.584017   True     Kyle Grusczynski  NaN
# 332      FR  77.584017   True          Pete Schmit  NaN
# 405      FR  80.000000  False       Butter Johnson  NaN
# 443      FR  79.000000  False       Gerald Wallace  NaN
# 545      SO  78.104591   True         Marcus Banta  NaN
# 552      JR  78.756728   True        Jarad Houston  NaN
# 610      FR  77.000000  False          RaMell Ross  NaN
# 617      JR  80.000000  False      Colin Boddicker  NaN
# 635      FR  78.000000  False          Orenn Fells  NaN
# 797      FR  77.066142   True     Ace Watanasuparp  NaN
# 846      FR  81.000000  False         Glen McGowan  NaN
# 847      FR  75.000000  False       Micah McKinney  NaN
# 946      SR  76.574899   True     Nashon McPherson  NaN
# 991     NaN  76.675335   True      Kevin Augustine  NaN
# 996     NaN  76.675335   True          Ben Chesnut  NaN
# 1005    NaN  76.675335   True       Marcus Thorton  NaN
# 1136     SR  72.000000  False         Larry Ashley  NaN
# 1148     FR  72.000000  False          Barry Welsh  NaN
# 1410     FR  79.000000  False      Michael Ayodele  NaN
# 1414     JR  78.000000  False        Warren Coates  NaN
# 1424     FR  79.000000  False         Casey Cortez  NaN
# 1426     FR  79.000000  False           Harry Good  NaN
# 1432     FR  75.000000  False           Ed McCants  NaN
# 1632     FR  72.000000  False       Jackiem Wright  NaN
# 1645    NaN  75.130534   True          Paul Bosela  NaN
# ...     ...        ...    ...                  ...  ...
# 41834   NaN  73.000000  False      Treadwell Lewis  NaN
# 41864   NaN  75.256864   True           Chris Wood  NaN
# 42011   NaN  76.000000  False   Franklin Henderson  NaN
# 42156   NaN  74.840696   True        Darrell Tripp  NaN
# 42184   NaN  72.000000  False      Mackenzie Casey  NaN
# 42251   NaN  82.000000  False        Antwyne Hines  NaN
# 42355   NaN  76.000000  False          Arman Rasul  NaN
# 42473   NaN  75.256864   True  Roderick McREYNOLDS  NaN
# 42474   NaN  73.000000  False       Jonathan Merit  NaN
# 42506   NaN  77.000000  False          Ricky Parks  NaN
# 42581   NaN  74.000000  False       Brandon Baylor  NaN
# 42605   NaN  74.000000  False         Jason Pancoe  NaN
# 42803   NaN  73.000000  False           Ben Martin  NaN
# 42815   NaN  74.848112   True          Donte Lopez  NaN
# 43007   NaN  81.000000  False         James Porter  NaN
# 43147   NaN  74.435693   True          Drew Godwin  NaN
# 43239   NaN  75.398026   True      Derrick Johnson  NaN
# 43347   NaN  72.000000  False         Chris Sights  NaN
# 43413   NaN  69.000000  False        George Dallas  NaN
# 43430   NaN  78.000000  False       Matt Mierzycki  NaN
# 43466   NaN  81.000000  False             Tim Lang  NaN
# 43618   NaN  75.398026   True          Greg Dillon  NaN
# 43621   NaN  75.398026   True        Jameel Forbes  NaN
# 43641   NaN  75.398026   True           Doug Scott  NaN
# 43648   NaN  79.000000  False      Gifford Blakely  NaN
# 43659   NaN  80.000000  False       Michael Starks  NaN
# 45848   NaN  73.486702   True        Adrian Tucker  NaN
# 47377   NaN  75.388626   True           Matt Cline  NaN
# 62258   NaN  75.398026   True          Terry Chase  NaN
# 66705   NaN  76.687268   True      Brandon Stewart  NaN
#
#                  player_link conf_clean  conference_id  class_id multipos  \
# 23         mike-schwertley-1     Pac-10             26         1        0
# 127        todd-kappelmann-1     Big 12              5         3        0
# 148            roger-mason-1        ACC              3         2        0
# 301           andy-ikeakor-1        SEC             29         1        0
# 323            ricky-bower-2    Big Ten              9         1        0
# 325       kyle-grusczynski-1    Big Ten              9         1        0
# 332            pete-schmit-2    Big Ten              9         1        0
# 405         butter-johnson-1       CUSA             12         1        0
# 443         gerald-wallace-1        SEC             29         1        0
# 545           marcus-banta-1    Big Ten              9         2        0
# 552          jarad-houston-1    Big Ten              9         3        0
# 610            ramell-ross-1   Big East              6         1        0
# 617        colin-boddicker-1        WAC             35         3        0
# 635            orenn-fells-1        SEC             29         1        0
# 797       ace-watanasuparp-1   Big East              6         1        0
# 846           glen-mcgowan-1        WCC             36         1        0
# 847         micah-mckinney-1        WCC             36         1        0
# 946       nashon-mcpherson-1   Sun Belt             34         4        0
# 991        kevin-augustine-1     Big 12              5         0        0
# 996            ben-chesnut-1     Big 12              5         0        0
# 1005        marcus-thorton-1     Big 12              5         0        0
# 1136          larry-ashley-1        MVC             20         4        0
# 1148           barry-welsh-1        MVC             20         1        0
# 1410       michael-ayodele-2   Big East              6         1        0
# 1414         warren-coates-1   Big East              6         3        0
# 1424          casey-cortez-1    Big Ten              9         1        0
# 1426            harry-good-1    Big Ten              9         1        0
# 1432            ed-mccants-1    Big Ten              9         1        0
# 1632        jackiem-wright-1       A-10              0         1        0
# 1645           paul-bosela-1    MW Coll             21         0        0
# ...                      ...        ...            ...       ...      ...
# 41834      treadwell-lewis-1        NEC             24         0        0
# 41864           chris-wood-1        OVC             25         0        0
# 42011   franklin-henderson-1        MAC             18         0        0
# 42156        darrell-tripp-1   Big West             10         0        0
# 42184      mackenzie-casey-1     Summit             33         0        0
# 42251        antwyne-hines-1       MEAC             19         0        0
# 42355          arman-rasul-1    Horizon             14         0        0
# 42473  roderick-mcreynolds-1        OVC             25         0        0
# 42474       jonathan-merit-1        OVC             25         0        0
# 42506          ricky-parks-1       SWAC             30         0        0
# 42581       brandon-baylor-1       MEAC             19         0        0
# 42605         jason-pancoe-1    Patriot             28         0        0
# 42803           ben-martin-1  Southland             32         0        0
# 42815          donte-lopez-1  Southland             32         0        0
# 43007         james-porter-1       MEAC             19         0        0
# 43147          drew-godwin-1        Ivy             16         0        0
# 43239      derrick-johnson-1       SWAC             30         0        0
# 43347         chris-sights-1       SWAC             30         0        0
# 43413        george-dallas-1       MAAC             17         0        0
# 43430       matt-mierzycki-1        GWC             13         0        0
# 43466             tim-lang-1      A-Sun              1         0        0
# 43618          greg-dillon-1       SWAC             30         0        0
# 43621        jameel-forbes-1       SWAC             30         0        0
# 43641           doug-scott-1       SWAC             30         0        0
# 43648      gifford-blakely-1       SWAC             30         0        0
# 43659       michael-starks-1       SWAC             30         0        0
# 45848        adrian-tucker-1        MAC             18         0        0
# 47377           matt-cline-1   Sun Belt             34         0        0
# 62258          terry-chase-1       SWAC             30         0        0
# 66705      brandon-stewart-1       MEAC             19         0        0
#
#       pos_primary  pos_id
# 23            NaN      -1
# 127           NaN      -1
# 148           NaN      -1
# 301           NaN      -1
# 323           NaN      -1
# 325           NaN      -1
# 332           NaN      -1
# 405           NaN      -1
# 443           NaN      -1
# 545           NaN      -1
# 552           NaN      -1
# 610           NaN      -1
# 617           NaN      -1
# 635           NaN      -1
# 797           NaN      -1
# 846           NaN      -1
# 847           NaN      -1
# 946           NaN      -1
# 991           NaN      -1
# 996           NaN      -1
# 1005          NaN      -1
# 1136          NaN      -1
# 1148          NaN      -1
# 1410          NaN      -1
# 1414          NaN      -1
# 1424          NaN      -1
# 1426          NaN      -1
# 1432          NaN      -1
# 1632          NaN      -1
# 1645          NaN      -1
# ...           ...     ...
# 41834         NaN      -1
# 41864         NaN      -1
# 42011         NaN      -1
# 42156         NaN      -1
# 42184         NaN      -1
# 42251         NaN      -1
# 42355         NaN      -1
# 42473         NaN      -1
# 42474         NaN      -1
# 42506         NaN      -1
# 42581         NaN      -1
# 42605         NaN      -1
# 42803         NaN      -1
# 42815         NaN      -1
# 43007         NaN      -1
# 43147         NaN      -1
# 43239         NaN      -1
# 43347         NaN      -1
# 43413         NaN      -1
# 43430         NaN      -1
# 43466         NaN      -1
# 43618         NaN      -1
# 43621         NaN      -1
# 43641         NaN      -1
# 43648         NaN      -1
# 43659         NaN      -1
# 45848         NaN      -1
# 47377         NaN      -1
# 62258         NaN      -1
# 66705         NaN      -1
#
# [895 rows x 16 columns]

# %%
dfAll.to_csv('rosters_imputed.csv', index = False)
